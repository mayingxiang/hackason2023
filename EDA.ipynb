# %%
import pandas as pd
am1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/amsterdam_weekdays_cleaned.csv")
am2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/amsterdam_weekends_cleaned.csv")
at1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/athens_weekdays_cleaned.csv")
at2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/athens_weekends_cleaned.csv")
ba1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/barcelona_weekdays_cleaned.csv")
ba2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/barcelona_weekends_cleaned.csv")
be1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/berlin_weekdays_cleaned.csv")
be2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/berlin_weekends_cleaned.csv")
bu1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/budapest_weekdays_cleaned.csv")
bu2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/budapest_weekends_cleaned.csv")
li1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/lisbon_weekdays_cleaned.csv")
li2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/lisbon_weekends_cleaned.csv")
lo1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/london_weekdays_cleaned.csv")
lo2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/london_weekends_cleaned.csv")
pa1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/paris_weekdays_cleaned.csv")
pa2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/paris_weekends_cleaned.csv")
ro1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/rome_weekdays_cleaned.csv")
ro2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/rome_weekends_cleaned.csv")
vi1=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/vienna_weekdays_cleaned.csv")
vi2=pd.read_csv("/Users/lvshihan/Documents/Airbnb Competition/data/vienna_weekends_cleaned.csv")

# %%
am1["city"]="Amsterdam"
am2["city"]="Amsterdam"
am1["weekend"]=0
am2["weekend"]=1
at1["city"]="Athens"
at2["city"]="Athens"
at1["weekend"]=0
at2["weekend"]=1
ba1["city"]="Barcelona"
ba2["city"]="Barcelona"
ba1["weekend"]=0
ba2["weekend"]=1
be1["city"]="Berlin"
be2["city"]="Berlin"
be1["weekend"]=0
be2["weekend"]=1
bu1["city"]="Budapest"
bu2["city"]="Budapest"
bu1["weekend"]=0
bu2["weekend"]=1
li1["city"]="Lisbon"
li2["city"]="Lisbon"
li1["weekend"]=0
li2["weekend"]=1
lo1["city"]="London"
lo2["city"]="London"
lo1["weekend"]=0
lo2["weekend"]=1
pa1["city"]="Paris"
pa2["city"]="Paris"
pa1["weekend"]=0
pa2["weekend"]=1
ro1["city"]="Rome"
ro2["city"]="Rome"
ro1["weekend"]=0
ro2["weekend"]=1
vi1["city"]="Vienna"
vi2["city"]="Vienna"
vi1["weekend"]=0
vi2["weekend"]=1

# %%
df=pd.concat([am1,am2,at1,at2,ba1,ba2,be1,be2,bu1,bu2,li1,li2,lo1,lo2,pa1,pa2,ro1,ro2,vi1,vi2]).reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47839 entries, 0 to 47838
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   realSum                     47839 non-null  float64
#  1   room_type                   47839 non-null  object
#  2   room_shared                 47839 non-null  bool
#  3   room_private                47839 non-null  bool
#  4   person_capacity             47839 non-null  float64
#  5   host_is_superhost           47839 non-null  bool
#  6   multi                       47839 non-null  int64
#  7   biz                         47839 non-null  int64
#  8   cleanliness_rating          47839 non-null  float64
#  9   guest_satisfaction_overall  47839 non-null  float64
#  10  bedrooms                    47839 non-null  int64
#  11  dist                        47839 non-null  float64
#  12  metro_dist                  47839 non-null  float64
# ...

# %%
df.head()
# Out:
#       realSum     room_type  room_shared  room_private  person_capacity  \
# 0  194.033698  Private room        False          True              2.0
# 1  433.529398  Private room        False          True              4.0
# 2  485.552926  Private room        False          True              2.0
# 3  552.808567  Private room        False          True              3.0
# 4  215.124317  Private room        False          True              2.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      1    0                10.0
# 1              False      0    1                 9.0
# 2               True      0    0                10.0
# 3              False      0    0                 8.0
# 4              False      0    0                10.0
#
#    guest_satisfaction_overall  ...      dist  metro_dist  attr_index  \
# 0                        93.0  ...  5.022964    2.539380   78.690379
# 1                        90.0  ...  0.384862    0.439876  493.272534
# ...

# %%
value_counts = df['city'].value_counts()
percentages = 100 * value_counts / len(df)

# Create a pie chart with the percentages as labels
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(value_counts, labels=percentages.index, autopct='%1.1f%%')

# Add a title
ax.set_title('City Distribution')

# Display the chart
plt.show()

# %%
value_counts = df['weekend'].value_counts()
percentages = 100 * value_counts / len(df)

# Create a pie chart with the percentages as labels
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(value_counts, labels=percentages.index, autopct='%1.1f%%')

# Add a title
ax.set_title('Weekend or Not Traveling Distribution')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot scatter plot of room price vs. person capacity
axs[0, 0].scatter(df['person_capacity'], df['realSum'])
axs[0, 0].set_xlabel('Person Capacity')
axs[0, 0].set_ylabel('Room Price')

# Plot scatter plot of room price vs. cleanliness rating
axs[0, 1].scatter(df['cleanliness_rating'], df['realSum'])
axs[0, 1].set_xlabel('Cleanliness Rating')
axs[0, 1].set_ylabel('Room Price')

# Plot scatter plot of room price vs. guest overall satisfaction score
axs[1, 0].scatter(df['guest_satisfaction_overall'], df['realSum'])
axs[1, 0].set_xlabel('Guest Satisfaction Score')
axs[1, 0].set_ylabel('Room Price')

# Plot scatter plot of room price vs. distance to downtown
axs[1, 1].scatter(df['dist'], df['realSum'])
axs[1, 1].set_xlabel('Distance to Downtown')
axs[1, 1].set_ylabel('Room Price')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# Display the figure
plt.show()

# %%
import seaborn as sns
num=df[["realSum","person_capacity","cleanliness_rating","guest_satisfaction_overall","dist"]]
corr = num.corr()
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.show()

# %%
# Create a box plot of room prices for each city
fig, ax = plt.subplots(figsize=(10, 8))
df.boxplot(column='realSum', by='city', ax=ax)

# Set the axis labels and title
ax.set_xlabel('City')
ax.set_ylabel('Room Price')
ax.set_title('Distribution of Room Prices by City')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# Display the figure
plt.show()

# %%
# Create a box plot of room prices for each city
fig, ax = plt.subplots(figsize=(10, 8))
df.boxplot(column='realSum', by='room_type', ax=ax)

# Set the axis labels and title
ax.set_xlabel('Type of Room')
ax.set_ylabel('Room Price')
ax.set_title('Distribution of Room Prices by Room Type')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# Display the figure
plt.show()

# %%
# Create a box plot of room prices for each city
fig, ax = plt.subplots(figsize=(10, 8))
df.boxplot(column='realSum', by='host_is_superhost', ax=ax)

# Set the axis labels and title
ax.set_xlabel('Is your Host a Super Host')
ax.set_ylabel('Room Price')
ax.set_title('Distribution of Room Prices by Host')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# Display the figure
plt.show()

# %%
# Create a box plot of room prices for each city
fig, ax = plt.subplots(figsize=(10, 8))
df.boxplot(column='realSum', by='weekend', ax=ax)

# Set the axis labels and title
ax.set_xlabel('Are you Travel on Weekends')
ax.set_ylabel('Room Price')
ax.set_title('Distribution of Room Prices by Travel Time')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# Display the figure
plt.show()

# %% [markdown]
# # Insights From EDA

# %% [markdown]
# · London, Rome and Paris are the top 3 cities appear on Airbnb. Which seems that they are the top 3 cities for traveling in Europe
# · Outliers exist in our dataset. Scaling should be neccessary done before model training
# · There is no strong correlation between room price and other variables in the dataset, it just have some correlation with person capacity
